# %% [markdown]
# ---
#
# # <font color= #6c9cda> *AurumQuant: FFNN–GARCH Risk Architecture* </font>
# - <Strong> Subject: </Strong>  <font color="#4875af">Non Linear Models  </font>
# - <Strong> 2nd Exam </Strong>  <font color="#4875af">FNN & GARCH </font>
#
# <div style="display: flex; align-items: center;">
#     <div style="flex: 1;">
#         <img src="https://oci02.img.iteso.mx/Identidades-De-Instancia/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" width="300">
#     </div>
# </div>
#
# ---
#
# ## <font color= #6c9cda> *Introduction* </font>

# %% [markdown]
# Aqui va la Introduccion (no sexual)

# %% [markdown]
# ---
#
# ## <font color= #6c9cda> *EDA y Limpieza* </font>

# %% [markdown]
# Aqui va el EDA

# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go

# %%
gold = yf.Ticker("GC=F")
df = gold.history(period="3mo", interval = "1d")

df.index.name = None
df
# Out:
#                                   Open         High          Low        Close  \
# 2026-01-06 00:00:00-05:00  4449.700195  4482.200195  4449.000000  4482.200195
# 2026-01-07 00:00:00-05:00  4450.000000  4450.000000  4449.299805  4449.299805
# 2026-01-08 00:00:00-05:00  4460.200195  4461.299805  4418.000000  4449.700195
# 2026-01-09 00:00:00-05:00  4473.000000  4490.299805  4473.000000  4490.299805
# 2026-01-12 00:00:00-05:00  4579.100098  4620.000000  4577.799805  4604.299805
# ...                                ...          ...          ...          ...
# 2026-03-31 00:00:00-04:00  4510.000000  4684.100098  4508.600098  4647.600098
# 2026-04-01 00:00:00-04:00  4668.399902  4789.100098  4668.000000  4783.200195
# 2026-04-02 00:00:00-04:00  4764.899902  4784.399902  4558.899902  4651.500000
# 2026-04-06 00:00:00-04:00  4656.100098  4689.600098  4605.000000  4656.799805
# 2026-04-07 00:00:00-04:00  4678.600098  4694.899902  4641.399902  4675.299805
#
#                            Volume  Dividends  Stock Splits
# 2026-01-06 00:00:00-05:00     459        0.0           0.0
# 2026-01-07 00:00:00-05:00     972        0.0           0.0
# 2026-01-08 00:00:00-05:00    2423        0.0           0.0
# 2026-01-09 00:00:00-05:00     237        0.0           0.0
# 2026-01-12 00:00:00-05:00     156        0.0           0.0
# ...                           ...        ...           ...
# 2026-03-31 00:00:00-04:00    4264        0.0           0.0
# 2026-04-01 00:00:00-04:00    1637        0.0           0.0
# 2026-04-02 00:00:00-04:00       0        0.0           0.0
# 2026-04-06 00:00:00-04:00       0        0.0           0.0
# 2026-04-07 00:00:00-04:00   18042        0.0           0.0
#
# [63 rows x 7 columns]

# %% [markdown]
# ---
#
# ## <font color= #6c9cda> *Pruebas de Estacionareidad* </font>

# %% [markdown]
# Aqui van las pruebas de estacionareidad

# %% [markdown]
# ---
#
# ## <font color= #6c9cda> *FNN* </font>

# %% [markdown]
# aQUI VA TODO PARA LA FNN

# %% [markdown]
# ---
#
# ## <font color= #6c9cda> *GARCH (O NO....)* </font>

# %% [markdown]
# Aqui va todo para GARCH

# %% [markdown]
# ---
#
# <div style="display: flex; justify-content: center; align-items: center;">
#     <img src="imgs/ivanmamado.png" width="300">
# </div>
#
# ---
